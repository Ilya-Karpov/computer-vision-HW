# %% [markdown]
# ## Dogs vs Cats
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.10.0
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('DvsC/train/*.jpg')
test_files = glob('DvsC/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD

# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  batch_normalization (BatchN  (None, 100352)           401408
#  ormalization)
#
#  dense_1 (Dense)             (None, 512)               51380736
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 59,419,969
# Trainable params: 51,582,977
# Non-trainable params: 7,836,992
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
val_samples = 5  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=30,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/30
# 10/10 [==============================] - 35s 3s/step - loss: 0.3251 - accuracy: 0.8875 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 2/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.3431 - accuracy: 0.8687 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 3/30
# 10/10 [==============================] - 36s 4s/step - loss: 0.3783 - accuracy: 0.8750 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 4/30
# 10/10 [==============================] - 36s 4s/step - loss: 0.4329 - accuracy: 0.8531 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 5/30
# 10/10 [==============================] - 35s 3s/step - loss: 0.2205 - accuracy: 0.9094 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 6/30
# 10/10 [==============================] - 40s 4s/step - loss: 0.3664 - accuracy: 0.8813 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 7/30
# 10/10 [==============================] - 40s 4s/step - loss: 0.2101 - accuracy: 0.9062 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 8/30
# 10/10 [==============================] - 35s 4s/step - loss: 0.2513 - accuracy: 0.9000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 9/30
# 10/10 [==============================] - 37s 4s/step - loss: 0.2814 - accuracy: 0.9031 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 10/30
# 10/10 [==============================] - 35s 4s/step - loss: 0.1983 - accuracy: 0.9312 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 11/30
# 10/10 [==============================] - 35s 4s/step - loss: 0.1930 - accuracy: 0.9125 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 12/30
# 10/10 [==============================] - 35s 3s/step - loss: 0.2438 - accuracy: 0.8969 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 13/30
# 10/10 [==============================] - 35s 4s/step - loss: 0.1934 - accuracy: 0.9219 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 14/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.1762 - accuracy: 0.9406 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 15/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.1916 - accuracy: 0.9344 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 16/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.2283 - accuracy: 0.9062 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 17/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.1716 - accuracy: 0.9438 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 18/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.2288 - accuracy: 0.9031 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 19/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.1896 - accuracy: 0.9344 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 20/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.1569 - accuracy: 0.9219 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 21/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.1888 - accuracy: 0.9281 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 22/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.1213 - accuracy: 0.9500 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 23/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.1679 - accuracy: 0.9344 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 24/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.2789 - accuracy: 0.9031 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 25/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.1789 - accuracy: 0.9156 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 26/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.1766 - accuracy: 0.9219 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 27/30
# 10/10 [==============================] - 34s 3s/step - loss: 0.1551 - accuracy: 0.9219 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 28/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.1721 - accuracy: 0.9219 - val_loss: 0.0310 - val_accuracy: 1.0000
# Epoch 29/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.2058 - accuracy: 0.9000 - val_loss: 0.0406 - val_accuracy: 1.0000
# Epoch 30/30
# 10/10 [==============================] - 33s 3s/step - loss: 0.2364 - accuracy: 0.9250 - val_loss: 0.0089 - val_accuracy: 1.0000

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))
# Out:
# 12500/12500 [==============================] - 1617s 129ms/step

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %% [markdown]
# ### Score: 0.15653
